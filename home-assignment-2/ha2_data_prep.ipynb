# %% [markdown]
# Dataset competition `https://www.kaggle.com/competitions/ga-customer-revenue-prediction/`
#
# Columns description `https://support.google.com/analytics/answer/3437719?hl=en`

# %%
import pandas as pd
from pathlib import Path
import json
from pandas import json_normalize
import numpy as np

# %% [markdown]
# # Load and prepare the data
#
# adopted (with changes) from `https://www.kaggle.com/code/ashrafkhan94/googleanalytics-customer-revenue-eda-prediction/notebook`

# %% [markdown]
# ### 1. Reading datafile (handling columns with Json Values)

# %%
columns = ['device', 'geoNetwork', 'totals', 'trafficSource'] # Columns that have json format

dir_path = Path('/anvar/public_datasets/ga-customer-revenue-data')

# p is a fractional number to skiprows and read just a random sample of the our dataset. 
p = 0.2 # *** In this case we will use 20% of data set *** #

#Code to transform the json format columns in table
def json_read(filename, random_state=17):
    data_frame = dir_path / filename
    random = np.random.RandomState(random_state)
    
    #Importing the dataset
    df = pd.read_csv(data_frame, 
                     converters={column: json.loads for column in columns}, # loading the json columns properly
                     dtype={'fullVisitorId': 'str'}, # transforming this column to string
                     skiprows=lambda i: i>0 and random.random() > p)
    
    for column in columns: #loop to finally transform the columns in data frame
        #It will normalize and set the json to a table
        column_as_df = json_normalize(df[column]) 
        # here will be set the name using the category and subcategory of json columns
        column_as_df.columns = [f"{column}.{subcolumn}" for subcolumn in column_as_df.columns] 
        # after extracting the values, let drop the original columns
        df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
    
    return df

# %%
df = json_read('train_v2.csv')

# %% [markdown]
# ### 2. Function to Describe each column

# %%
def DataDesc(df):
    print(f"Dataset Shape: {df.shape}")
    summary = pd.DataFrame(df.dtypes,columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name','dtypes']]
    summary['Missing'] = df.isnull().sum().values    
    summary['Uniques'] = df.nunique().values
    summary['First Value'] = df.loc[0].values
    summary['Second Value'] = df.loc[1].values
    summary['Third Value'] = df.loc[2].values
    return summary

# %%
DataDesc(df)
# Out:
# Dataset Shape: (341831, 59)
#                                                  Name  dtypes  Missing  \
# 0                                     channelGrouping  object        0
# 1                                    customDimensions  object        0
# 2                                                date   int64        0
# 3                                       fullVisitorId  object        0
# 4                                                hits  object        0
# 5                                socialEngagementType  object        0
# 6                                             visitId   int64        0
# 7                                         visitNumber   int64        0
# 8                                      visitStartTime   int64        0
# 9                                      device.browser  object        0
# 10                              device.browserVersion  object        0
# 11                                 device.browserSize  object        0
# 12                             device.operatingSystem  object        0
# 13                      device.operatingSystemVersion  object        0
# 14                                    device.isMobile    bool        0
# 15                        device.mobileDeviceBranding  object        0
# 16                           device.mobileDeviceModel  object        0
# 17                         device.mobileInputSelector  object        0
# 18                            device.mobileDeviceInfo  object        0
# 19                   device.mobileDeviceMarketingName  object        0
# 20                                device.flashVersion  object        0
# 21                                    device.language  object        0
# 22                                device.screenColors  object        0
# 23                            device.screenResolution  object        0
# 24                              device.deviceCategory  object        0
# 25                               geoNetwork.continent  object        0
# 26                            geoNetwork.subContinent  object        0
# 27                                 geoNetwork.country  object        0
# 28                                  geoNetwork.region  object        0
# 29                                   geoNetwork.metro  object        0
# 30                                    geoNetwork.city  object        0
# 31                                  geoNetwork.cityId  object        0
# 32                           geoNetwork.networkDomain  object        0
# 33                                geoNetwork.latitude  object        0
# 34                               geoNetwork.longitude  object        0
# 35                         geoNetwork.networkLocation  object        0
# 36                                      totals.visits  object        0
# 37                                        totals.hits  object        0
# 38                                   totals.pageviews  object       60
# 39                                  totals.timeOnSite  object   174911
# 40                                   totals.newVisits  object    80214
# 41                           totals.sessionQualityDim  object   167520
# 42                                totals.transactions  object   338125
# 43                          totals.transactionRevenue  object   338138
# 44                     totals.totalTransactionRevenue  object   338138
# 45                                     totals.bounces  object   167480
# 46                             trafficSource.campaign  object        0
# 47                               trafficSource.source  object        0
# 48                               trafficSource.medium  object        0
# 49                         trafficSource.isTrueDirect  object   234916
# 50  trafficSource.adwordsClickInfo.criteriaParameters  object        0
# 51                              trafficSource.keyword  object   210664
# 52                         trafficSource.referralPath  object   228671
# 53                trafficSource.adwordsClickInfo.page  object   326641
# 54                trafficSource.adwordsClickInfo.slot  object   326641
# 55               trafficSource.adwordsClickInfo.gclId  object   326609
# 56       trafficSource.adwordsClickInfo.adNetworkType  object   326641
# 57           trafficSource.adwordsClickInfo.isVideoAd  object   326641
# 58                            trafficSource.adContent  object   328759
#
#     Uniques                                        First Value  \
# 0         8                                             Direct
# 1         6         [{'index': '4', 'value': 'North America'}]
# 2       638                                           20171016
# 3    311212                                7992466427990357681
# 4    298377  [{'hitNumber': '1', 'time': '0', 'hour': '17',...
# 5         1                               Not Socially Engaged
# 6    339614                                         1508201613
# 7       314                                                  1
# 8    339668                                         1508201613
# 9        54                                             Chrome
# 10        1                      not available in demo dataset
# 11        1                      not available in demo dataset
# 12       21                                            Android
# 13        1                      not available in demo dataset
# 14        2                                               True
# 15        1                      not available in demo dataset
# 16        1                      not available in demo dataset
# 17        1                      not available in demo dataset
# 18        1                      not available in demo dataset
# 19        1                      not available in demo dataset
# 20        1                      not available in demo dataset
# 21        1                      not available in demo dataset
# 22        1                      not available in demo dataset
# 23        1                      not available in demo dataset
# 24        3                                             mobile
# 25        6                                           Americas
# 26       23                                   Northern America
# 27      210                                      United States
# 28      463                      not available in demo dataset
# 29      121                      not available in demo dataset
# 30      889                      not available in demo dataset
# 31        1                      not available in demo dataset
# 32    16992                                windjammercable.net
# 33        1                      not available in demo dataset
# 34        1                      not available in demo dataset
# 35        1                      not available in demo dataset
# 36        1                                                  1
# 37      200                                                  2
# 38      152                                                  2
# 39     3315                                                 38
# 40        1                                                  1
# 41       99                                                  1
# 42       10                                                NaN
# 43     2115                                                NaN
# 44     2477                                                NaN
# 45        1                                                NaN
# 46       31                                          (not set)
# 47      231                                           (direct)
# 48        7                                             (none)
# 49        1                                               True
# 50        1                      not available in demo dataset
# 51     1292                                                NaN
# 52     1741                                                NaN
# 53        7                                                NaN
# 54        3                                                NaN
# 55    13948                                                NaN
# 56        3                                                NaN
# 57        1                                                NaN
# 58       63                                                NaN
#
#                                          Second Value  \
# 0                                      Organic Search
# 1                   [{'index': '4', 'value': 'EMEA'}]
# 2                                            20171016
# 3                                 9075655783635761930
# 4   [{'hitNumber': '1', 'time': '0', 'hour': '9', ...
# 5                                Not Socially Engaged
# 6                                          1508169851
# 7                                                   1
# 8                                          1508169851
# 9                                              Chrome
# 10                      not available in demo dataset
# 11                      not available in demo dataset
# 12                                            Windows
# 13                      not available in demo dataset
# 14                                              False
# 15                      not available in demo dataset
# 16                      not available in demo dataset
# 17                      not available in demo dataset
# 18                      not available in demo dataset
# 19                      not available in demo dataset
# 20                      not available in demo dataset
# 21                      not available in demo dataset
# 22                      not available in demo dataset
# 23                      not available in demo dataset
# 24                                            desktop
# 25                                               Asia
# 26                                       Western Asia
# 27                                             Turkey
# 28                      not available in demo dataset
# 29                      not available in demo dataset
# 30                      not available in demo dataset
# 31                      not available in demo dataset
# 32                                    unknown.unknown
# 33                      not available in demo dataset
# 34                      not available in demo dataset
# 35                      not available in demo dataset
# 36                                                  1
# 37                                                  2
# 38                                                  2
# 39                                                  1
# 40                                                  1
# 41                                                  1
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                          (not set)
# 47                                             google
# 48                                            organic
# 49                                                NaN
# 50                      not available in demo dataset
# 51                                     (not provided)
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
#
#                                           Third Value
# 0                                      Organic Search
# 1        [{'index': '4', 'value': 'Central America'}]
# 2                                            20171016
# 3                                  632878546807742341
# 4   [{'hitNumber': '1', 'time': '0', 'hour': '19',...
# 5                                Not Socially Engaged
# 6                                          1508207516
# 7                                                   1
# 8                                          1508207516
# 9                                              Chrome
# 10                      not available in demo dataset
# 11                      not available in demo dataset
# 12                                          Macintosh
# 13                      not available in demo dataset
# 14                                              False
# 15                      not available in demo dataset
# 16                      not available in demo dataset
# 17                      not available in demo dataset
# 18                      not available in demo dataset
# 19                      not available in demo dataset
# 20                      not available in demo dataset
# 21                      not available in demo dataset
# 22                      not available in demo dataset
# 23                      not available in demo dataset
# 24                                            desktop
# 25                                           Americas
# 26                                    Central America
# 27                                             Mexico
# 28                                        Mexico City
# 29                                          (not set)
# 30                                        Mexico City
# 31                      not available in demo dataset
# 32                                  uninet-ide.com.mx
# 33                      not available in demo dataset
# 34                      not available in demo dataset
# 35                      not available in demo dataset
# 36                                                  1
# 37                                                  2
# 38                                                  2
# 39                                                 34
# 40                                                  1
# 41                                                  1
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                          (not set)
# 47                                             google
# 48                                            organic
# 49                                                NaN
# 50                      not available in demo dataset
# 51                                     (not provided)
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN

# %% [markdown]
# - Notice there are a lot of constant columns having only one unique value
# - Target column = totals.transactionRevenue (Null value = No Revenue)
# - Columns with prefix trafficSource contain Null values majorly, hence we will drop these columns
#
#
#
# ### 3. Describing Columns with Null Values

# %%
def Null_Count(df):
    df_null = df.isnull().sum().sort_values(ascending = False).rename('Null').reset_index()

    null_count = df_null['Null']
    null_percent = (null_count * 100) / (df.shape[0])

    df_null = pd.concat([df_null['index'], null_count,null_percent], axis=1,
                        keys=['Column','Null_Count','Null_Percent'])

    return df_null[df_null['Null_Count'] != 0]

Null_Count(df)
# Out:
#                                           Column  Null_Count  Null_Percent
# 0                 totals.totalTransactionRevenue      338138     98.919642
# 1                      totals.transactionRevenue      338138     98.919642
# 2                            totals.transactions      338125     98.915839
# 3                        trafficSource.adContent      328759     96.175888
# 4       trafficSource.adwordsClickInfo.isVideoAd      326641     95.556284
# 5   trafficSource.adwordsClickInfo.adNetworkType      326641     95.556284
# 6            trafficSource.adwordsClickInfo.slot      326641     95.556284
# 7            trafficSource.adwordsClickInfo.page      326641     95.556284
# 8           trafficSource.adwordsClickInfo.gclId      326609     95.546922
# 9                     trafficSource.isTrueDirect      234916     68.722848
# 10                    trafficSource.referralPath      228671     66.895922
# 11                         trafficSource.keyword      210664     61.628114
# 12                             totals.timeOnSite      174911     51.168852
# 13                      totals.sessionQualityDim      167520     49.006673
# 14                                totals.bounces      167480     48.994971
# 15                              totals.newVisits       80214     23.465982
# 16                              totals.pageviews          60      0.017553

# %% [markdown]
# ### 4. Function to Fill Null Values

# %%
def fill_na(df):   
    df['totals.pageviews'].fillna(1, inplace=True)
    df['totals.newVisits'].fillna(0, inplace=True)
    df['totals.bounces'].fillna(0, inplace=True) 
    df['totals.transactionRevenue'].fillna(0.0, inplace=True)
    df['totals.totalTransactionRevenue'].fillna(0.0, inplace=True)
    df['totals.transactions'].fillna(0, inplace=True)
    df['totals.timeOnSite'].fillna(0, inplace=True)
    df['totals.sessionQualityDim'].fillna(0, inplace=True)
    
    # Changing datatypes from object to desired ones
    df['totals.pageviews'] = df['totals.pageviews'].astype(np.int32)
    df['totals.newVisits'] = df['totals.newVisits'].astype(np.int32)
    df['totals.bounces'] = df['totals.bounces'].astype(np.int32)
    df['totals.transactionRevenue'] = df['totals.transactionRevenue'].astype(np.float32)
    df['totals.totalTransactionRevenue'] = df['totals.totalTransactionRevenue'].astype(np.float32)
    df['totals.transactions'] = df['totals.transactions'].astype(np.int32)
    df['totals.sessionQualityDim'] = df['totals.sessionQualityDim'].astype(np.float32)
    df['totals.hits'] = df['totals.hits'].astype(np.int32)
    df['totals.timeOnSite'] = df['totals.timeOnSite'].astype(np.float32)
    
    df['trafficSource.isTrueDirect'].fillna(False, inplace=True) 
    df['trafficSource.adwordsClickInfo.isVideoAd'].fillna(True, inplace=True) # filling boolean with True
    df[df['geoNetwork.city'] == "(not set)"]['geoNetwork.city'] = np.nan
    df['geoNetwork.city'].fillna("NaN", inplace=True)

    df['visitNumber'] = df['visitNumber'].astype(np.int32)

  
    return df

df = fill_na(df)
# Out:
# <ipython-input-7-e9afd5968a6e>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['geoNetwork.city'] == "(not set)"]['geoNetwork.city'] = np.nan

# %% [markdown]
# ### 5. Processing Date/Time Columns

# %%
from datetime import datetime

# This function is to extract date features
def date_process(df):
    df["date"] = pd.to_datetime(df["date"], format="%Y%m%d") # seting the column as pandas datetime
    df["weekday"] = df['date'].dt.weekday #extracting week day
    df["day"] = df['date'].dt.day # extracting day
    df["month"] = df['date'].dt.month # extracting day
    df["year"] = df['date'].dt.year # extracting day
    df['visitHour'] = (df['visitStartTime'].apply(lambda x: str(datetime.fromtimestamp(x).hour))).astype(int)
    
    return df.drop('date', axis=1)

df = date_process(df)

# %% [markdown]
# ### 6. Removing constant columns

# %%
constant_columns = [col for col in df.columns if df[col].nunique() == 1]

for col in constant_columns:
    print(col)
print(f'Num of Columns : {len(constant_columns)}')

df.drop(constant_columns, axis=1, inplace=True)
# Out:
# socialEngagementType
# device.browserVersion
# device.browserSize
# device.operatingSystemVersion
# device.mobileDeviceBranding
# device.mobileDeviceModel
# device.mobileInputSelector
# device.mobileDeviceInfo
# device.mobileDeviceMarketingName
# device.flashVersion
# device.language
# device.screenColors
# device.screenResolution
# geoNetwork.cityId
# geoNetwork.latitude
# geoNetwork.longitude
# geoNetwork.networkLocation
# totals.visits
# trafficSource.adwordsClickInfo.criteriaParameters
# Num of Columns : 19

# %% [markdown]
# ### 7. Dropping Null Columns

# %%
nulls = Null_Count(df)
nulls
# Out:
#                                          Column  Null_Count  Null_Percent
# 0                       trafficSource.adContent      328759     96.175888
# 1           trafficSource.adwordsClickInfo.page      326641     95.556284
# 2  trafficSource.adwordsClickInfo.adNetworkType      326641     95.556284
# 3           trafficSource.adwordsClickInfo.slot      326641     95.556284
# 4          trafficSource.adwordsClickInfo.gclId      326609     95.546922
# 5                    trafficSource.referralPath      228671     66.895922
# 6                         trafficSource.keyword      210664     61.628114

# %%
cols_to_drop = ['trafficSource.adContent', 'trafficSource.adwordsClickInfo.page',
                'trafficSource.adwordsClickInfo.adNetworkType',
                'trafficSource.adwordsClickInfo.slot',
                'trafficSource.adwordsClickInfo.gclId',
                'trafficSource.referralPath', 'trafficSource.keyword',
                'geoNetwork.networkDomain', 'geoNetwork.region', 'geoNetwork.metro',
               'visitStartTime', 'visitId']

df.drop(cols_to_drop, axis=1, inplace=True)

# %% [markdown]
# ### 8. Serialize remaining json columns

# %%
def split_json(x):
    dictionary = json.loads(x.replace("'", '"'))
    if len(dictionary) > 0:
        return dictionary[0]
    else:
        return {'index': np.nan, 'value':'Unknown'}

custom_dimensions = df.customDimensions.apply(split_json)
custom_dimensions_cols = pd.DataFrame.from_records(custom_dimensions.values).rename(
    columns={'index': 'customDimensions.index', 'value':'customDimensions.value'})

df = df.merge(custom_dimensions_cols, right_index=True, left_index=True)
df.drop(['hits', 'customDimensions', 'customDimensions.index', 'totals.transactions'], axis=1, inplace=True)

# %% [markdown]
# ### 9. Prepare target column

# %%
df.drop(['totals.transactionRevenue'], axis=1, inplace=True)

# %% [markdown]
# ### 10. Prep bool columns

# %%
df['device.isMobile'] = df['device.isMobile'].astype(np.int32)
df['trafficSource.isTrueDirect'] = df['trafficSource.isTrueDirect'].astype(np.int32)
df['trafficSource.adwordsClickInfo.isVideoAd'] = df['trafficSource.adwordsClickInfo.isVideoAd'].astype(np.int32)

# %% [markdown]
# #  Split and save data for HA

# %%
from sklearn.model_selection import train_test_split

# %%
train_id, test_id = train_test_split(df.fullVisitorId, train_size=0.7)
train, test = df[df.fullVisitorId.isin(train_id)], df[df.fullVisitorId.isin(test_id)]

# %%
def return_X_y(df):
    X = df.drop(['fullVisitorId', 'totals.totalTransactionRevenue'], axis=1)    
    y = df['totals.totalTransactionRevenue']
    return X, y

X_train, y_train = return_X_y(train)
X_test, y_test = return_X_y(test)

# %%
X_train.merge(y_train, right_index=True, left_index=True).reset_index(drop=True).to_csv('/home/anvar/ha2_train.csv', index=False)
X_test.merge(y_test, right_index=True, left_index=True).reset_index(drop=True).to_csv('/home/anvar/ha2_test.csv', index=False)

# %%
df_train = pd.read_csv('/home/anvar/ha2_train.csv')
df_train.head()
# Out:
#   channelGrouping  visitNumber device.browser device.operatingSystem  \
# 0  Organic Search            1         Chrome              Macintosh
# 1  Organic Search            1         Chrome                Windows
# 2  Organic Search            1         Chrome                  Linux
# 3  Organic Search            1         Chrome                Android
# 4  Organic Search            1         Chrome                  Linux
#
#    device.isMobile device.deviceCategory geoNetwork.continent  \
# 0                0               desktop             Americas
# 1                0               desktop             Americas
# 2                0               desktop                 Asia
# 3                1                mobile             Americas
# 4                0               desktop                 Asia
#
#   geoNetwork.subContinent geoNetwork.country                geoNetwork.city  \
# 0         Central America             Mexico                    Mexico City
# 1        Northern America             Canada  not available in demo dataset
# 2            Eastern Asia             Taiwan  not available in demo dataset
# 3        Northern America             Canada  not available in demo dataset
# 4           Southern Asia              India  not available in demo dataset
#
#    ...  trafficSource.medium  trafficSource.isTrueDirect  \
# 0  ...               organic                           0
# 1  ...               organic                           0
# 2  ...               organic                           0
# 3  ...               organic                           0
# 4  ...               organic                           0
#
#    trafficSource.adwordsClickInfo.isVideoAd  weekday  day  month  year  \
# 0                                         1        0   16     10  2017
# 1                                         1        0   16     10  2017
# 2                                         1        0   16     10  2017
# 3                                         1        0   16     10  2017
# 4                                         1        0   16     10  2017
#
#   visitHour customDimensions.value  totals.totalTransactionRevenue
# 0         5        Central America                             0.0
# 1        20          North America                             0.0
# 2         9                   APAC                             0.0
# 3         4          North America                             0.0
# 4        22                   APAC                             0.0
#
# [5 rows x 28 columns]

# %%
df_train.shape
# Out:
# (251396, 28)

# %%
df_test = pd.read_csv('/home/anvar/ha2_test.csv')
df_test.head()
# Out:
#   channelGrouping  visitNumber device.browser device.operatingSystem  \
# 0          Direct            1         Chrome                Android
# 1  Organic Search            1         Chrome                Windows
# 2  Organic Search            1         Safari              Macintosh
# 3  Organic Search            1         Safari                    iOS
# 4  Organic Search            1         Safari              Macintosh
#
#    device.isMobile device.deviceCategory geoNetwork.continent  \
# 0                1                mobile             Americas
# 1                0               desktop                 Asia
# 2                0               desktop               Europe
# 3                1                mobile             Americas
# 4                0               desktop               Europe
#
#   geoNetwork.subContinent geoNetwork.country                geoNetwork.city  \
# 0        Northern America      United States  not available in demo dataset
# 1            Western Asia             Turkey  not available in demo dataset
# 2         Northern Europe             Sweden  not available in demo dataset
# 3        Northern America      United States  not available in demo dataset
# 4          Western Europe            Belgium  not available in demo dataset
#
#    ...  trafficSource.medium  trafficSource.isTrueDirect  \
# 0  ...                (none)                           1
# 1  ...               organic                           0
# 2  ...               organic                           0
# 3  ...               organic                           0
# 4  ...               organic                           0
#
#    trafficSource.adwordsClickInfo.isVideoAd  weekday  day  month  year  \
# 0                                         1        0   16     10  2017
# 1                                         1        0   16     10  2017
# 2                                         1        0   16     10  2017
# 3                                         1        0   16     10  2017
# 4                                         1        0   16     10  2017
#
#   visitHour customDimensions.value  totals.totalTransactionRevenue
# 0         3          North America                             0.0
# 1        19                   EMEA                             0.0
# 2        16                   EMEA                             0.0
# 3         1          North America                             0.0
# 4        11                   EMEA                             0.0
#
# [5 rows x 28 columns]

# %%
df_test.shape
# Out:
# (118506, 28)
