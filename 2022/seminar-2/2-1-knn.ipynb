# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
plt.rc('font', **{'size':18})

# %%
df = pd.read_csv('https://raw.githubusercontent.com/rmcelreath/rethinking/master/data/Howell1.csv', sep=';')
df = df.query('age>18')
df.head(3)
# Out:
#     height     weight   age  male
# 0  151.765  47.825606  63.0     1
# 1  139.700  36.485807  63.0     0
# 2  136.525  31.864838  65.0     0

# %%
plt.figure(figsize=(10, 5))

plt.scatter(df.query("male==0")['height'], df.query("male==0")['weight'],
            c='tab:red', s=100, alpha=0.5, label='female')
plt.scatter(df.query("male==1")['height'], df.query("male==1")['weight'],
            c='tab:blue', s=100, alpha=0.5, label='male')
plt.scatter(158, 52, marker='x', s=200, edgecolors='tab:green', label='?')

plt.xlabel('Height')
plt.ylabel('Weight')
plt.legend()
plt.title('What is the label of green cross?');

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df_train, df_test = train_test_split(df, test_size=0.33, shuffle=True, random_state=1)

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df_train['height'], df_train['weight'],
            c='tab:green', s=50, alpha=0.5, label='Train points')
plt.scatter(df_test['height'], df_test['weight'],
            c='tab:gray', s=20, alpha=0.8, label='Test points')

plt.xlabel('Height')
plt.ylabel('Weight')
plt.legend();

# %% [markdown]
# # K = 1

# %%
X_train, y_train = df_train[['height', 'weight']], df_train['male']
X_test, y_test = df_test[['height', 'weight']], df_test['male']

# %%
knn_clf = KNeighborsClassifier(n_neighbors=1)

knn_clf.fit(X_train, y_train)
y_pred_train = knn_clf.predict(X_train)
y_pred_test = knn_clf.predict(X_test)

# %%
accuracy_score(y_train, y_pred_train)
# Out:
# 1.0

# %%
accuracy_score(y_test, y_pred_test)
# Out:
# 0.7739130434782608

# %% [markdown]
# # K = 2,3,4,...10

# %%
acc_test = []
acc_train = []

for k in range(1,10):
    model = KNeighborsClassifier(n_neighbors = k)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    y_pred_train = model.predict(X_train)
    
    acc_test.append(accuracy_score(y_test, y_pred))
    acc_train.append(accuracy_score(y_train, y_pred_train))

# %%
plt.figure(figsize=(15,5))

plt.plot(range(1,10), acc_test, label='test accuracy');
plt.plot(range(1,10), acc_train, label='train accuracy');

plt.scatter(range(1,10), acc_test);
plt.scatter(range(1,10), acc_train);

plt.xlabel('Number of neighbours k')
plt.ylabel('Accuracy score');
plt.legend();

# %% [markdown]
# # Increase K

# %%
acc_test = []
acc_train = []
max_k = 30
for k in range(1,max_k):
    model = KNeighborsClassifier(n_neighbors = k)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    y_pred_train = model.predict(X_train)
    
    acc_test.append(accuracy_score(y_test, y_pred))
    acc_train.append(accuracy_score(y_train, y_pred_train))

# %%
plt.figure(figsize=(15,5))

plt.plot(range(1,max_k), acc_test, label='test accuracy');
plt.plot(range(1,max_k), acc_train, label='train accuracy');

plt.scatter(range(1,max_k), acc_test);
plt.scatter(range(1,max_k), acc_train);

plt.xlabel('Number of neighbours k')
plt.ylabel('Accuracy score');
plt.grid()
plt.legend();

# %%
np.argmax(acc_test)
# Out:
# 6

# %%
acc_test[np.argmax(acc_test)]
# Out:
# 0.8434782608695652

# %%
best_clf_knn = KNeighborsClassifier(6)
best_clf_knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=6)

# %% [markdown]
# # Questions
#
# 1. KNN generalization. How good will be predictions on kids?
# 2. How to get probability instead of class label?
# 3. How to adapt for classification?
# 4. What if we have same number of different classes amongst neighbours (e.g. 2 "male" and 2 "female" )?
#
# # Другие параметры KNN
#
# 1. Choose distance metric (euclidean, minkowski, cosine, etc.).
# 2. Выбор взвешивания (примеров в зависимости от близости к данному).

# %%
df = pd.read_csv('https://raw.githubusercontent.com/rmcelreath/rethinking/master/data/Howell1.csv', sep=';')
df_kids = df.query('age<=18')

# %%
y_pred = best_clf_knn.predict(df_kids[['height', 'weight']])
# print(accuracy_score(df_kids['male'], y_pred))

# %% [markdown]
# # Упражнение 1.
# # Имплементировать KNN c sklearn-подобным интерфейсом
#
# - Имплементируйте метод к ближайших соседей
# - Сравните скорость его работы с `sklearn` имплементацией, используйте `%%time`, `%%timeit`
# - Посмотрите как изменяется время предсказания в зависимости от
#     - признаковой размерности выборки;
#     - количества наблюдений в обучающей выборке.
#
# В качестве набора данных используйте синтетические данные `sklearn.datasets.make_blobs`.

# %%
class KNN:
    """
    Naive KNN classifier
    """
    
    def __init__(self, k):
        self.k = k
        
    def fit(self, X, y):
        self.X = X
        self.y = y
    
    def predict(self, X):
        y = []
        assert len(X.shape) == 2
        for (h, w) in X:
            ### Посчитаем расстояние от всех элементов в тренировочной выборке
            # до текущего примера -> результат - вектор размерности трейна
            d = ...
            ### Возьмем индексы k элементов, расстояние до которых минимально
            ### результат -> вектор из k элементов
            idx = ...
            ### Посчитаем частоту меток для каждого случая 
            ### результат -> вектор длины С (классов), который покажет
            ### сколько соседей 0-го класса, сколько соседей 1-го класса и так далее до C.
            counts = ...
            ### возьмем самый часто встречаемый в соседях класс.
            prediction = ...
            y.append(prediction)
        return y

# %% [markdown]
# # Упражнение 2. Работа с таблицами с помощью библиотеки `pandas`.
